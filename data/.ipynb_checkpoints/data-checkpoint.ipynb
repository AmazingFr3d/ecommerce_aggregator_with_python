# %%
# Out:
# The system cannot find the path specified.

# %%
import pandas as pd

data = pd.read_csv('Arduino_Uno_data.csv')
data['price'] = data['price'].str.replace('$', '')
data['price'] = data['price'].str.replace(',', '')
data['price'] = data['price'].str.replace(' ', '')
data['price'] = data['price'].str.replace('₦', '')
data['price'] = data['price'].astype(float)

data
# Out:
# C:\Users\Nengus\AppData\Local\Temp\ipykernel_12116\1728219940.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['price'] = data['price'].str.replace('$', '')
#                                                  name     price        site
# 0   HiLetgo UNO R3 D1 R32 ESP32 ESP-32 CH340G WiFi...    123.82  amazon.com
# 1   ELEGOO Mega Project The Most Complete Ultimate...     15.55  amazon.com
# 2   ELEGOO UNO R3 Project Most Complete Starter Ki...     17.99  amazon.com
# 3   KEYESTUDIO Plus Board for Arduino UNO R3 with ...     18.99  amazon.com
# 4                    Arduino Mega 2560 REV3 [A000067]     20.99  amazon.com
# 5                             Arduino Zero [ABX00003]    225.99  amazon.com
# 6                    Arduino UNO WiFi REV2 [ABX00021]     26.99  amazon.com
# 7                          Arduino UNO REV3 [A000066]     28.50  amazon.com
# 8                      Arduino UNO SMD REV3 [A000073]     29.95  amazon.com
# 9   ELEGOO UNO R3 Board ATmega328P with USB Cable(...     29.95  amazon.com
# 10  GAR Monster Starter Kit for Arduino Uno Mega N...     29.99  amazon.com
# 11  Mini Nano V3.0 ATmega328P Microcontroller Boar...     43.47  amazon.com
# 12  ARDUINO 2243680 K000007 Starter Kit with Compa...     44.99  amazon.com
# 13  ELEGOO UNO Project Super Starter Kit with Tuto...     58.00  amazon.com
# 14                              Arduino Due [A000056]     59.99  amazon.com
# 15  Treedix 2pcs ATmega328P CH340 Development Boar...     63.94  amazon.com
# 16  CNC Shield V3 Engraving Machine 3D Printer+ 4p...  11285.00   jumia.com
# 17  CNC Shield V3 Engraving Machine 3D Printer+ 4p...  11285.00   jumia.com
# 18  GRBL CNC Motherboard TTL Control Plate MKS DLC...  11466.00   jumia.com
# 19  GRBL CNC Motherboard TTL Control Plate MKS DLC...  11466.00   jumia.com
# 20   For Arduino Uno R3 DIY Kit R3 Board / Breadboard  11741.00   jumia.com
# 21  GRBL CNC Motherboard 3 Axis Driver Plate Cnc S...  12997.00   jumia.com
# 22  For Arduino Uno R3 DIY Kit R3 Board / Breadboa...  13031.00   jumia.com
# 23                            Arduino Uno R3 + Camera  14000.00   jumia.com
# 24  UNO Project Super Starter Kit With Tutorial, U...  14600.00   jumia.com
# 25  4WD  Bluetooth Multi-functional DIY Smart Car ...  16126.00   jumia.com
# 26  CNC Shield V3 Engraving Machine 3D Printer+ 4p...  17188.00   jumia.com
# 27  For Arduino Uno R3 DIY Kit R3 Board / Breadboa...  18563.00   jumia.com
# 28  For Arduino Uno R3 DIY Kit R3 Board / Breadboa...  19831.00   jumia.com
# 29  For UNO Project Super Starter Kit with Tutoria...   2242.00   jumia.com
# 30  Super Starter Kit For Arduino UNO R3 Upgraded ...  28557.00   jumia.com
# 31  Super Starter Kit For Arduino UNO R3 Upgraded ...  28557.00   jumia.com
# 32  Super Starter Kit For Arduino UNO R3 Upgraded ...  28790.00   jumia.com
# 33  Most Complete Starter Kit For Arduino UNO R3 +...  30000.00   jumia.com
# 34  Super Starter Kit for Arduino UNO R3 Upgraded ...  32454.00   jumia.com
# 35  Super Starter Kit for Arduino UNO R3 Upgraded ...  34560.00   jumia.com
# 36  Arduino  Uno Rev3 ATmega328 Microcomputer boar...  34560.00   jumia.com
# 37  Super Starter Kit For Arduino UNO R3 Upgraded ...  36498.00   jumia.com
# 38  Super Starter Kit for Arduino UNO R3 Upgraded ...  53086.00   jumia.com
# 39  ESP8266 ESP-01 ESP01 Serial WiFi Wireless Adap...   6519.00   jumia.com
# 40  ESP8266 ESP-01 ESP01 Serial WiFi Wireless Adap...   6519.00   jumia.com
# 41  CNC V3 Reprap Shield Engraving Machine A4988 D...   6623.00   jumia.com
# 42  42 Stepper Motor Driver Expansion Board DRV882...   6630.00   jumia.com
# 43  Cnc Shield V3 UNO R3 Expansion Panel GRBL 1.1 ...   7523.00   jumia.com
# 44  Cnc Shield V3 UNO R3 Expansion Panel GRBL 1.1 ...   7523.00   jumia.com
# 45  CNC V3 Reprap Shield Engraving Machine A4988 D...   7530.00   jumia.com
# 46  For WeMos D1 Mini CH340 WiFi Development Board...   7856.00   jumia.com
# 47                                     Arduino UNO R3   8000.00   jumia.com
# 48  Cnc Shield V3 UNO R3 Expansion Board GRBL 1.1 ...   8258.00   jumia.com
# 49  Cnc Shield V3 UNO R3 Expansion Panel GRBL 1.1 ...   8396.00   jumia.com
# 50  CNC Shield V3 Engraving Machine 3D Printer+ 4p...   8604.00   jumia.com
# 51  CNC Shield Expansion Board V3.0 +UNO R3 Board ...   8743.00   jumia.com
# 52  CNC Shield Expansion Board V3.0 +UNO R3 Board ...   8743.00   jumia.com
# 53  3D Printer CNC Shield V3.0 Expansion Board + 4...   9470.00   jumia.com
# 54  3D Printer CNC Shield V3.0 Expansion Board + 4...   9470.00   jumia.com
# 55  3D Printer CNC Shield V3.0 Expansion Board + 4...   9470.00   jumia.com

# %%
string = '432.37 Nigerian Naira'
str_list = string.split()
